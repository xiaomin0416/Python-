# %% [markdown]
# # Matplotlib数据可视化基础
# ## 6.1 Matplotlib简介
# 在Jupyter Notebook中进行交互式绘图，需要执行以下语句：% matplotlib notebook
# 导入包：import matplotlib.pyplot as plt
# ## 6.2 绘图基础
# ### 6.2.1创建画布与子图
# 常用方法：
#
# |函数名称|函数作用|
# |:--:|:--:|
# |plt.figure|创建一个空白画布，可指定画布大小
# |figure.add_subplot|创建兵选中子图，可指定子图函数、列数与选中图片编号

# %%
# 例6-1 创建子图
# %matplotlib notebook
# %matplotlib inline
import matplotlib.pyplot as plt
fig = plt.figure()
#不能使用空白的figure绘图，需要创建子图
ax1 = fig.add_subplot(2,2,1)
ax2 = fig.add_subplot(2,2,2)
ax3 = fig.add_subplot(2,2,3)

# %%
# 例 6-2 绘制子图

fig = plt.figure()
ax1 = fig.add_subplot(2,2,1)
ax2 = fig.add_subplot(2,2,2)
ax3 = fig.add_subplot(2,2,3)
ax1.plot([1.5,2,3,3.5,-1,1.6])

# %%
# 例 6-3 创建子图序列
# plt.subplots()创建新画布，并返回包含了已经生成的子图对象Numpy数组，，数组axes数组可以像二维数组索引

fig,axes = plt.subplots(2,3)

# %%
# 例 6-4 调整子图周围的间距

import numpy as np
# sharex,sharey表示子图拥有相同的x轴和y轴
fig,axes = plt.subplots(2,2,sharex = True,sharey = True)
for i in range(2):
    for j in range(2):
        axes[i,j].hist(np.random.randn(500),bins = 50,color = 'k',alpha = 0.5)
plt.subplots_adjust(wspace = 0,hspace = 0)  # wspace:子图之间宽度，hspace:子图之间高度

# %% [markdown]
# subplot子图调整间距
# 参考：https://guokliu.blog.csdn.net/article/details/79424858?utm_medium=distribute.pc_relevant.none-task-blog-BlogCommendFromBaidu-3.control&depth_1-utm_source=distribute.pc_relevant.none-task-blog-BlogCommendFromBaidu-3.control

# %% [markdown]
# ### 添加画布内容
# 设置绘图的属性没有先后顺序，都是并列的。单添加图例必须在绘制图形之后，Pyplot添加各类标签和图例函数如下：
#
# |函数名称|函数说明|
# |:--:|:--:|
# |plt.title|当前图形中添加标题，可指定标题名称、位置、颜色、字体大小等
# |plt.xlabel|当前图片中添加X轴名称，可指定位置、颜色、字体等
# |plt.ylabel|当前图片中添加Y轴名称，可指定位置、颜色、字体等
# |plt.xlim|指定当前图片X轴的范围，只能确定一个数值区间
# |plt.ylim|指定当前图片Y轴的范围，只能确定一个数值区间
# |plt.xticks|指定X轴刻度的数目与取值
# |plt.yticks|指定Y轴刻度的数目与取值
# |plt.legend|指定当前图片的图例，可指定图例的大小、位置、标签。参数loc设置图例的位置，如'best','upper right'。参数fontsize设置字体大小
#
# plt.legend(loc='best', frameon=False)  # 去掉图例边款
# plt.legend(loc='best',edgecolor='blue') # 设置图例边款颜色
# plt.legend(loc='best', facecolor='blue') # 设置图例背景颜色，若无边框则无效

# %%
# 例 6-5 绘图时设置坐标轴属性

data = np.arange(0,1,0.01)
plt.title('my lines example')
plt.xlabel('X')
plt.ylabel('Y')
plt.xlim(0,1)
plt.ylim(0,1)
plt.xticks([0,0.2,0.4,0.6,0.8,1])
plt.yticks([0,0.2,0.4,0.6,0.8,1])
plt.tick_params(labelsize = 12)  #Tick label font size in points or as a string (e.g., 'large').
plt.plot(data,data**2)
plt.plot(data,data**3)
plt.legend(['y = x^2','y = x^3'])
plt.show()

# %%
plt.tick_params?

# %%
# 例 6-6 包含子图绘制的基础语法

data = np.arange(0,np.pi*2,0.01)
fig1 = plt.figure(figsize = (9,7),dpi = 90)       #确定画布大小
ax1 = fig1.add_subplot(1,2,1)            #绘制第1幅子图
plt.title('lines example')
plt.xlabel('X')
plt.ylabel('Y')
plt.xlim(0,1)
plt.ylim(0,1)
plt.xticks([0,0.2,0.4,0.6,0.8,1])
plt.yticks([0,0.2,0.4,0.6,0.8,1])
plt.plot(data,data**2)
plt.plot(data,data**3)
plt.legend(['y = x^2','y = x^3'])       #绘制第2幅子图
ax1 = fig1.add_subplot(1,2,2)
plt.title('sin-cos')
plt.xlabel('X')
plt.ylabel('Y')
plt.xlim(0,np.pi*2)
plt.ylim(-1,1)
plt.xticks([0,np.pi/2,np.pi,np.pi*3/2,np.pi*2])
plt.yticks([-1,-0.5,0,0.5,1])
plt.plot(data,np.sin(data))
plt.plot(data,np.cos(data))
plt.legend(['sin','cos'])
plt.show()

# %% [markdown]
# ### 6.2.3绘图保存与显示
# |函数名称|函数作用|
# |:--:|:--:|
# |plt.savefig|保存绘制的图形，可指定图形的参数，如fname:文件路径霍Python文件型对象字符串；dpi:分辨率；facecolor,edgecolor:子图之外的图形背景颜色；format:文件格式；bbox_inchs:保存图片的范围
# |plt.show|在本机显示图形

# %% [markdown]
# ## 6.3 设置Pyplot的动态rc参数
#
# Matplotlib配置了配色方案和默认设置，有两种方式设置参数：全局参数定制和rc设置
#
# 查看rc参数：
# import matplotlib as plt
# print(plt.rc_params())
# ### 6.3.1 全局参数定制

# %%
# 例 6-7 查看用户的配置文件目录

import matplotlib as plt
print(plt.matplotlib_fname())
# Out:
# F:\py\lib\site-packages\matplotlib\mpl-data\matplotlibrc

# %% [markdown]
# 找到配置文件目录，修改matplotlibrc文件即可修改配置参数
# ### 6.3.2 rc参数设置
# 参考官方文档：http://matplotlib.org/3.2.1/api/_as_gen/matplotlib.pyplot.rc.html

# %%
plt.rc?

# %%
import matplotlib.pyplot as plt

plt.subplot(311)
plt.plot([1, 2, 3])

# the axes attributes need to be set before the call to subplot
plt.rc('font', weight='bold')
plt.rc('xtick.major', size=5, pad=7)
plt.rc('xtick', labelsize=15)

# using aliases for color, linestyle and linewidth; gray, solid, thick
plt.rc('grid', c='0.5', ls='-', lw=5)
plt.rc('lines', lw=2, color='g')
plt.subplot(312)

plt.plot([1, 2, 3])
plt.grid(True)

plt.rcdefaults()
plt.subplot(313)
plt.plot([1, 2, 3])
plt.grid(True)
plt.show()

# %%
# 例 6-8 rc参数设置示例1
import numpy as np
import matplotlib.pyplot as plt
fig,ax = plt.subplots()
#配置中文显示
plt.rcParams['font.family'] = ['SimHei']
plt.rcParams['axes.unicode_minus'] = False
def f(t):
    return np.cos(2*np.pi*t)
x1 = np.arange(0.0,4.0,0.5)
x2 = np.arange(0.0,4.0,0.01)
plt.figure(1)
plt.subplot(2,2,1)
plt.plot(x1,f(x1),'bo',x2,f(x2),'k')  #'bo':蓝色的点
plt.title('子图1')
plt.subplot(2,2,2)
plt.plot(np.cos(2*np.pi*x2),'r--')
plt.title('子图2')
plt.show()

# %%
# 例 6-9 rc参数设置示例2

fig = plt.figure()
ax = fig.add_subplot(1,1,1)
ax.plot(np.random.randn(30).cumsum(),color = 'k',linestyle = 'dashed',marker = 'o',label = 'one')
ax.plot(np.random.randn(30).cumsum(),color = 'k',linestyle = 'dashed',marker = '+',label = 'two')
ax.plot(np.random.randn(30).cumsum(),color = 'k',linestyle = 'dashed',marker = 'v',label = 'three')
ax.legend(loc = 'best')

# %%
# 例 6-10 用set_xticks设置刻度

fig = plt.figure()
ax = fig.add_subplot(1,1,1)
ax.plot(np.random.randn(30).cumsum(),color = 'k',linestyle = 'dashed',marker = 'o',label = 'one')
ax.plot(np.random.randn(30).cumsum(),color = 'k',linestyle = 'dashed',marker = '+',label = 'two')
ax.plot(np.random.randn(30).cumsum(),color = 'k',linestyle = 'dashed',marker = 'v',label = 'three')
ax.set_xticks([0,5,10,15,20,25,30,35])
ax.legend(loc = 'best')

# %%
#例 6-11 用set_xticklabels改变刻度

fig = plt.figure()
ax = fig.add_subplot(1,1,1)
ax.plot(np.random.randn(30).cumsum(),color = 'k',linestyle = 'dashed',marker = 'o',label = 'one')
ax.plot(np.random.randn(30).cumsum(),color = 'k',linestyle = 'dashed',marker = '+',label = 'two')
ax.plot(np.random.randn(30).cumsum(),color = 'k',linestyle = 'dashed',marker = 'v',label = 'three')
ax.set_xticklabels(['x1','x2','x3','x4','x5'],rotation = 30,fontsize = 'large')
ax.legend(loc = 'best')

# %% [markdown]
# ### 6.3.3 绘图的填充
# #### 1.调用函数fill_between()实现曲线下面部分区域的填充

# %%
#例 6-12 使用fill_between()填充区域

x = np.linspace(0,1,500)
y = np.sin(3*np.pi*x)*np.exp(-4*x)
fig,ax = plt.subplots()
plt.plot(x,y)
plt.fill_between(x,0,y,facecolor = 'green',alpha = 0.3)  # where表示填充的条件

# %% [markdown]
# #### 2.部分区域的填充

# %%
# 例 6-13 使用fill_between()填充部分区域

plt.plot(x,y)
plt.fill_between(x[15:300],0,0.4,facecolor = 'green',alpha = 0.3)

# %% [markdown]
# #### 3.两条曲线之间的区域填充

# %%
# 例 6-14 使用fill_between()填充曲线之间的区域

x = np.linspace(0,1,500)
y1 = np.sin(3*np.pi*x)*np.exp(-4*x)
y2 = y1+0.2
plt.plot(x,y1,'b')
plt.plot(x,y2,'r')
plt.fill_between(x,y1,y2,facecolor = 'green',alpha = 0.3)
plt.show()

# %% [markdown]
# #### 4.直接使用fill进行绘图填充

# %%
# 例 6-15 使用fill进行绘图的填充

x = np.linspace(0,1,500)
y = np.sin(3*np.pi*x)*np.exp(-4*x)
fig,ax = plt.subplots()
ax.fill(x,y)  # 函数与坐标轴之间的区域进行填充
plt.show()

# %% [markdown]
# ### 6.3.4 文本注解
# 通过text函数指定位置（x,y）在图表上加入注解。

# %%
# 例 6-16 绘制气温柱状图并标注

import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['font.family'] = ['SimHei']
data = [25,30,32,34,34,23]
label = ['西宁','兰州','北京','上海','广州','拉萨']
plt.xticks(range(len(data)),label)
plt.xlabel('城市')
plt.ylabel('温度')
plt.title('六城市8月份日均最高气温')
plt.bar(range(len(data)),data)
for x,y in zip(range(len(data)),data):
    print(x,y)
    plt.text(x,y,y,ha = 'center',va = 'bottom')
plt.show()
# Out:
# 0 25
# 1 30
# 2 32
# 3 34
# 4 34
# 5 23

# %% [markdown]
# ## 6.4 Pyplot中的常用绘图
# ### 6.4.1 折线图

# %%
# 例 6-17 简单折线图绘制

x1 = np.arange(0,30)
plt.plot(x1,x1*2,'b')
plt.show()

# %%
# 例 6-18 带点的折线图绘制

x1 = np.arange(0,30)
plt.plot(x1,x1*2,'b')
plt.plot(x1,x1*2,'bo')
plt.show()

# %% [markdown]
# ### 6.4.2 散点图

# %%
# 例 6-19 scatter绘图示例1

fig,ax = plt.subplots()
plt.rcParams['font.family'] = ['SimHei']
plt.rcParams['axes.unicode_minus'] = False

x1 = np.arange(1,30)
y1 = np.sin(x1)
ax1 = plt.subplot(1,1,1)
plt.title('散点图')
plt.xlabel('X')
plt.ylabel('Y')
lvalue = x1
ax1.scatter(x1,y1,c = 'r',s = 100,linewidths = lvalue,marker = 'o')
plt.legend('x1')
plt.show()

# %%
# 例 6-20 scatter绘图示例2

fig,ax = plt.subplots()
plt.rcParams['font.family'] = ['SimHei']
plt.rcParams['axes.unicode_minus'] = False

for color in ['red','green','blue']:
    n = 500
    x,y = np.random.randn(2,n)
    ax.scatter(x,y,c = color,label = color,alpha = 0.3,edgecolors = 'none')
ax.legend()
ax.grid(True)
plt.show()

# %% [markdown]
# ### 6.4.3 直方图

# %%
# 例 6-21 bar绘图示例1

import pandas as pd
fig,axes = plt.subplots(2,1)
data = pd.Series(np.random.randn(16),index = list('abcdefghijklmnop'))
print(data)
data.plot.bar(ax = axes[0],color = 'k',alpha = 0.7)   #垂直柱状图
data.plot.barh(ax = axes[1],color = 'k',alpha = 0.7)   #alpha设置透明度
# Out:
# a    0.548997
# b    1.123416
# c   -0.339070
# d   -0.404397
# e   -1.558812
# f    2.169253
# g    0.787794
# h   -1.140622
# i    0.145699
# j   -0.019682
# k   -1.269365
# l    0.376059
# m   -0.101596
# n   -0.217629
# o    0.935946
# p    0.059151
# dtype: float64

# %%
#例 6-22 bar绘图示例2

fig,ax = plt.subplots()
plt.rcParams['font.family'] = ['SimHei']
plt.rcParams['axes.unicode_minus'] = False

x = np.arange(1,6)
Y1 = np.random.uniform(1.5,1.0,5)
Y2 = np.random.uniform(1.5,1.0,5)
plt.bar(x,Y1,width = 0.35,facecolor = 'lightskyblue',edgecolor = 'white')
plt.bar(x+0.35,Y2,width = 0.35,facecolor = 'yellowgreen',edgecolor = 'white')
plt.show()

# %% [markdown]
# ### 6.4.4 饼图

# %%
# 例 6-23 pie绘图示例1

plt.figure(figsize = (6,6))
ax = plt.axes([0.1,0.1,0.8,0.8])
#建立轴的大小
labels = ['Springs','Summer','Autumn','Winter']
x = [15,30,45,10]
explode = (0.05,0.05,0.05,0.05)
#这个是控制分离的距离的，默认饼图不分离
plt.pie(x,labels = labels,explode = explode,startangle=60,autopct='%1.1f%%')
#sutopct在图中显示比例值，注意值的格式
plt.title('Rany days by season')
plt.tick_params(labelsize = 12)
plt.show()

# %% [markdown]
# ### 6.4.5 箱线图

# %%
# 例 6-24 boxplot绘图示例1

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
np.random.seed(2)    #设置随机种子
df = pd.DataFrame(np.random.randn(5,4),columns=['A','B','C','D'])
print(df)  # 生成0~1的5*4维度数据并存入4列DataFrame中
df.boxplot()     #也可用plot.box()
plt.show()
# Out:
#           A         B         C         D
# 0 -0.416758 -0.056267 -2.136196  1.640271
# 1 -1.793436 -0.841747  0.502881 -1.245288
# 2 -1.057952 -0.909008  0.551454  2.292208
# 3  0.041539 -1.117925  0.539058 -0.596160
# 4 -0.019130  1.175001 -0.747871  0.009025

# %% [markdown]
# ### 6.4.6 概率图

# %%
# 例 6-25 绘制概率图

fig,ax = plt.subplots()
plt.rcParams['font.family'] = ['SimHei']
plt.rcParams['axes.unicode_minus'] = False
np.random.seed(1587554)
mu = 100
sigma = 15
x = mu+sigma*np.random.randn(437)
num_bins = 50
n,bins,patches = ax.hist(x,num_bins,density = 1)
y = plt.mlab.normpdf(bins,mu,sigma)
ax.plot(bins,y,'--')
fig.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-57-ae23c09cc0b0> in <module>
#      10 num_bins = 50
#      11 n,bins,patches = ax.hist(x,num_bins,density = 1)
# ---> 12 y = plt.mlab.normpdf(bins,mu,sigma)
#      13 ax.plot(bins,y,'--')
#      14 fig.tight_layout()
#
# AttributeError: module 'matplotlib.mlab' has no attribute 'normpdf'

# %%
plt.mlab?

# %% [markdown]
# ## 6.5 词云
# 1. 安装相关包：
# pip istall wordcloud
# pip install jieba
#
# 2. 词云生成：
# 分析的数据转换成列表
# 对列表事业粉刺工具jieba进行遍历分词
# 用wordcloud设置词云图片属性、掩码、停用词，并生成词云图片
#
# 3. 次云生成示例：
# 例6-26 首先在智联招聘网站爬取“Java软件开发工程师”的薪资、岗位职责及任职要求数据，然后选取任职要求数据（requirements）进行分析并生成词云。

# %%
import jieba
import pandas as pd
import matplotlib.pyplot as plt
from wordcloud import WordCloud,STOPWORDS
from Scipy.misc import imread
def get_wordList():
    df = pd.read_excel()
    wordList = df['requirements'].tolist()
    return wordList
def get_wordClound(mylist):
    word_list = ["".join(jieba.cut(sentence))for sentence in mylist]
    new_text = ''.join(word_list)
    pic_path = ''
    img_mask = imread(pic_path)
    wordcloud = WorddCloud(background_color = "white",
                           font_path = '/home/shen/Downloads/front/msyh.ttc',mask = img_mask,
                          stopwords = STOPWORDS,).generate(new_text)
    plt.imshow(wordcloud)
    plt.axis("off")
    plt.show()
if __name__=='_-main__':
    wordList = get_wordList()
    get_wordClound(wordList)

# %% [markdown]
# ## 6.6 本章小结
# Pyplot绘图的基本语法、常用参数、各类常用图形的绘制和词云的简单用法
# ## 本章实训
# 全球星巴克门店统计数据

# %%
# 导入模块

import pandas as pd
import numpy as np
from pandas import Series,DataFrame
import matplotlib.pyplot as plt
plt.rcParams['font.sans-serif'] = ['SimHei']
plt.rcParams['axes.unicode_minus'] = False
# %matplotlib inline

# 获取数据

starbucks = pd.read_csv("directory.csv")
starbucks.head()

# %%
# 数据分析及可视化
## 查看星巴克旗下有哪些品牌。如果我们只关心星巴克咖啡门店，则只需获取
##星巴克中Brand的数据集，并查看全世界一共有多少家星巴克门店。
print("星巴克旗下品牌有：\n",starbucks.Brand.value_counts())
coffee = starbucks[starbucks.Brand == 'Starbucks']
print("\n",coffee.shape)

## 查看全世界一共有多少个国家和地区开设了星巴克门店，显示门店数量排名
##前10和后10的国家和地区。
df = starbucks.groupby(["Country"]).size()
print("全世界一共有多少个国家和地区开设了星巴克门店：",df.size)
df1 = df.sort_values(ascending = False)
print("排名前10的国家和地区：\n",df1.head(10))

### 星巴克门店数排名后10的国家：
print("排名后10的国家：\n",df1.tail(10))

# %%
## 用柱状图绘制排名前10的分布情况。
plt.rcParams['font.size'] = 15
plt.rcParams['font.family'] = 'SimHei'
df1.head(10).plot(kind = 'bar',rot = 0)
plt.title('星巴克门店数排名前10的国家和地区')
plt.ylabel('Store Counts')
plt.xlabel('Countries and Regions')

## 显示拥有星巴克门店数量排名前10的城市。
count_starbucks_city = coffee.City.value_counts()
print("星巴克门店数量排名前10的城市：\n",
     count_starbucks_city.head(10))
star = starbucks.dropna(how = 'any',subset = ['City'])
count_starbucks_city = star.City.value_counts()
print("全世界星巴克门店数量排名前10的城市：\n",
     count_starbucks_city.head(10))

# %%
##绘制星巴克门店前10的城市分布柱状图。
plt.figure(1,figsize = (8,6))
count_starbucks_city = star.City.value_counts()
city_top10 = count_starbucks_city.head(10)
city_top10.plot(kind = 'bar',rot = 30)
plt.title('拥有星巴克门店最多的10个城市')
plt.ylabel('Store Counts')
plt.xlabel('City')

## 按照星巴克门店在中国的分布情况，统计排名前10的城市。
import pinyin
#选择中国的数据
df = star[star["Country"] == "CN"]
df1 = df.copy()
#将城市名改为小写
df1["City"] = df1["City"].apply(lambda x:x.lower())
#将汉字城市名改为小写拼音，去掉“市”的拼音
df1["City"] = df1["City"].apply(
    lambda x:pinyin.get(x,format = "strip",delimiter = "")[0:-3])
#统计每个城市的星巴克门店数量
df1 = df1.gruopby(["City"]).size().sort_values(ascending = False)
df1.head(10)

# %%
## 绘制柱状图。
df1.head(10).plot(kind = 'bar',rot = 30)
plt.title('中国拥有星巴克门店最多的10个城市')
plt.ylabel('Store Counts')
plt.xlabel('Cities')

## 用饼状图显示星巴克门店的经营方式有哪几种。
plt.figure(1,figsize = (8,6))
ownership = star['Ownership Type'].value_counts()
plt.title('星巴克门店所有权类型')
ownership.plot(kind = 'pie')
